# %% [markdown]
# # Report on Houston ISD

# %%
import os 
current_dir = r"C:\Users\mmath\OneDrive\Desktop\Capstone\HERC_Sp25\4_Data_Modeling\4.2 Nearest Neighbor Model Validation\Nearest Neighbors Model Helper Functions"
os.chdir(current_dir)

# %%
from getData import load_data_from_github
from compareNeighbors import comparePlotter, compareMetrics
from KNN_Model import find_nearest_districts

from Demographic_Buckets import student_teacher_ratio
from Demographic_Buckets import student_count
from Demographic_Buckets import staff_count
from Demographic_Buckets import race_ethnicity_percent
from Demographic_Buckets import economically_disadvantaged
from Demographic_Buckets import special_ed_504
from Demographic_Buckets import language_education_percent
from Demographic_Buckets import special_populations_percent
from Demographic_Buckets import gifted_students
from Demographic_Buckets import district_identifiers

import pandas as pd

# %%
df, key = load_data_from_github(2023)
houstonISD = 101912
# Out:
# https://raw.githubusercontent.com/RiceD2KLab/HERC_Sp25/refs/heads/main/5_Dashboard_Development/data/2023/merged_2023.csv
#       DISTRICT_id  District 2022 Attendance: All Students Days Present  \
# 0            1902                                            84674.0
# 1            1903                                           170556.0
# 2            1904                                           122113.0
# 3            1906                                            46835.0
# 4            1907                                           459581.5
# ...           ...                                                ...
# 1204       252902                                            29341.0
# 1205       252903                                            91460.0
# 1206       253901                                           454489.0
# 1207       254901                                           233590.5
# 1208       254902                                            65560.0
#
# ...

# %%
all_neighbors = compareMetrics(district_id = houstonISD, df = df)

# %%
pd.DataFrame({'Unique Neighbors': all_neighbors['DISTNAME'][all_neighbors['DISTRICT_id'] != houstonISD].unique()})
# Out:
#     Unique Neighbors
# 0         ALDINE ISD
# 1          MANOR ISD
# 2        SHELDON ISD
# 3      HEMPSTEAD ISD
# 4      ARLINGTON ISD
# 5     FORT WORTH ISD
# 6        WHARTON ISD
# 7  GRAND PRAIRIE ISD
# 8          ROYAL ISD

# %% [markdown]
# ## Economically Disadvantaged

# %%
from KNN_Diagnostic_Plots import plot_economically_disadvantaged_side_by_side, plot_texas_districts
from compareNeighbors import plot_demographic_feature_presence2
econ_dis = comparePlotter(houstonISD, plot_func = plot_economically_disadvantaged_side_by_side, df = df, selected_features = economically_disadvantaged)
econ_dis
# Out:
#      DISTRICT_id          DISTNAME    metric
# 532       101912       HOUSTON ISD  Method 1
# 443        91906       SHERMAN ISD  Method 1
# 228        48903    PAINT ROCK ISD  Method 1
# 421        84908     HITCHCOCK ISD  Method 1
# 966       200906         OLFEN ISD  Method 1
# 532       101912       HOUSTON ISD  Method 2
# 443        91906       SHERMAN ISD  Method 2
# 421        84908     HITCHCOCK ISD  Method 2
# 228        48903    PAINT ROCK ISD  Method 2
# 865       175903     CORSICANA ISD  Method 2
# 532       101912       HOUSTON ISD  Method 3
# 443        91906       SHERMAN ISD  Method 3
# 362        71902       EL PASO ISD  Method 3
# 712       137901    KINGSVILLE ISD  Method 3
# 228        48903    PAINT ROCK ISD  Method 3
# 532       101912       HOUSTON ISD  Method 4
# 160        31909  POINT ISABEL ISD  Method 4
# 445        91908   VAN ALSTYNE ISD  Method 4
# 158        31905      LA FERIA ISD  Method 4
# 362        71902       EL PASO ISD  Method 4
# ...

# %% [markdown]
# ## Student Race and Ethnicity

# %%
from KNN_Diagnostic_Plots import plot_race_ethnicity_stacked_bar
re = comparePlotter(houstonISD, plot_func = plot_race_ethnicity_stacked_bar, df = df, selected_features = race_ethnicity_percent)
re
plot_demographic_feature_presence2(re, houstonISD)
# Out:
# DISTNAME  Houston ISD  Arlington ISD  Fort Worth ISD  Goose Creek CISD  \
# metric
# Method 1          1.0            1.0             1.0               0.0
# Method 2          1.0            0.0             1.0               0.0
# Method 3          1.0            1.0             1.0               0.0
# Method 4          1.0            0.0             1.0               0.0
# Method 5          1.0            0.0             1.0               1.0
#
# DISTNAME  Grand Prairie ISD  Hempstead ISD  Manor ISD  Mesquite ISD  \
# metric
# Method 1                1.0            0.0        1.0           0.0
# Method 2                1.0            0.0        1.0           0.0
# Method 3                1.0            0.0        1.0           0.0
# Method 4                0.0            1.0        1.0           1.0
# Method 5                1.0            0.0        1.0           0.0
#
# DISTNAME  Wharton ISD
# metric
# Method 1          0.0
# Method 2          1.0
# Method 3          0.0
# ...

# %% [markdown]
# ## Bilingual and Language Education

# %%
import matplotlib as plt
plt.rcParams['axes.grid'] = False

from KNN_Diagnostic_Plots import plot_language_education_bars
bil_lan = comparePlotter(houstonISD, plot_func = plot_language_education_bars, df = df, selected_features = language_education_percent)
bil_lan
plot_demographic_feature_presence2(bil_lan, houstonISD)
# Out:
# DISTNAME  Houston ISD  Carrollton-Farmers Branch ISD  Castleberry ISD  \
# metric
# Method 1          1.0                            0.0              0.0
# Method 2          1.0                            0.0              0.0
# Method 3          1.0                            1.0              1.0
# Method 4          1.0                            0.0              0.0
# Method 5          1.0                            0.0              0.0
#
# DISTNAME  Edinburg CISD  Grand Prairie ISD  Mcallen ISD  Mckinney ISD  \
# metric
# Method 1            1.0                1.0          1.0           0.0
# Method 2            1.0                1.0          1.0           0.0
# Method 3            0.0                0.0          0.0           0.0
# Method 4            0.0                0.0          0.0           1.0
# Method 5            1.0                1.0          1.0           0.0
#
# DISTNAME  Schertz-Cibolo-U City ISD  Sealy ISD  Sheldon ISD  \
# metric
# ...

# %% [markdown]
# ## Model based on all available variables

# %%
from KNN_Diagnostic_Plots import plot_student_teacher_ratio_bars, plot_gifted_talented_bars
all_features_neighbors = compareMetrics(houstonISD, df = df, selected_features = gifted_students + race_ethnicity_percent + student_count + staff_count + economically_disadvantaged + language_education_percent + special_populations_percent + special_ed_504 + student_teacher_ratio)
all_features_neighbors
plot_demographic_feature_presence2(all_features_neighbors, houstonISD)
plt.rcParams['axes.grid'] = False

comparePlotter(district_id = houstonISD, plot_func = plot_student_teacher_ratio_bars, df = df, selected_features= gifted_students + race_ethnicity_percent + student_count + staff_count + economically_disadvantaged + language_education_percent + special_populations_percent + special_ed_504 + student_teacher_ratio)
comparePlotter(district_id = houstonISD, plot_func = plot_gifted_talented_bars, df = df, selected_features= gifted_students + race_ethnicity_percent + student_count + staff_count + economically_disadvantaged + language_education_percent + special_populations_percent + special_ed_504 + student_teacher_ratio)
# Out:
#       DISTRICT_id                       DISTNAME    metric
# 532        101912                    HOUSTON ISD  Method 1
# 285         57905                     DALLAS ISD  Method 1
# 528        101907          CYPRESS-FAIRBANKS ISD  Method 1
# 91          15915                  NORTHSIDE ISD  Method 1
# 534        101914                       KATY ISD  Method 1
# 532        101912                    HOUSTON ISD  Method 2
# 285         57905                     DALLAS ISD  Method 2
# 1040       220905                 FORT WORTH ISD  Method 2
# 528        101907          CYPRESS-FAIRBANKS ISD  Method 2
# 524        101902                     ALDINE ISD  Method 2
# 532        101912                    HOUSTON ISD  Method 3
# 91          15915                  NORTHSIDE ISD  Method 3
# 528        101907          CYPRESS-FAIRBANKS ISD  Method 3
# 844        170902                     CONROE ISD  Method 3
# 1091       227901                     AUSTIN ISD  Method 3
# ...

# %%
from KNN_Diagnostic_Plots import plot_special_ed_504_bar
sp_504 = comparePlotter(houstonISD, plot_func = plot_special_ed_504_bar, df = df, selected_features = special_ed_504)
sp_504
plot_demographic_feature_presence2(sp_504, houstonISD)
# Out:
# DISTNAME  Houston ISD  Arlington ISD  Ben Bolt-Palito Blanco ISD  \
# metric
# Method 1          1.0            0.0                         0.0
# Method 2          1.0            0.0                         0.0
# Method 3          1.0            0.0                         0.0
# Method 4          1.0            1.0                         1.0
# Method 5          1.0            0.0                         0.0
#
# DISTNAME  Lancaster ISD  Mumford ISD  Pasadena ISD  Pringle-Morse CISD  \
# metric
# Method 1            1.0          1.0           0.0                 1.0
# Method 2            1.0          1.0           0.0                 1.0
# Method 3            1.0          1.0           0.0                 1.0
# Method 4            0.0          0.0           1.0                 0.0
# Method 5            1.0          1.0           0.0                 1.0
#
# DISTNAME  River Road ISD  San Perlita ISD
# metric
# Method 1             0.0              1.0
# ...
