# %%
import os

# %%
current_directory = r"C:\Users\mmath\OneDrive\Desktop\Capstone\HERC_Sp25\4_Data_Modeling\4.1 Nearest Neighbor Model"
os.chdir(current_directory)

# %%
from KNN_Model import find_nearest_districts
df, demographic_buckets, neighbors = find_nearest_districts(2023, 1902, ['student_teacher_ratio'])
# Out:
# https://raw.githubusercontent.com/RiceD2KLab/HERC_Sp25/refs/heads/main/5_Dashboard_Development/data/2023/merged_2023.csv
#       DISTRICT_id  District 2022 Attendance: All Students Days Present  \
# 0            1902                                            84674.0
# 1            1903                                           170556.0
# 2            1904                                           122113.0
# 3            1906                                            46835.0
# 4            1907                                           459581.5
# ...           ...                                                ...
# 1204       252902                                            29341.0
# 1205       252903                                            91460.0
# 1206       253901                                           454489.0
# 1207       254901                                           233590.5
# 1208       254902                                            65560.0
#
# ...

# %%
neighbors
# Out:
#      DISTRICT_id                        DISTNAME
# 248        55901  CULBERSON COUNTY-ALLAMOORE ISD
# 410        82902                      DILLEY ISD
# 861       174908             CENTRAL HEIGHTS ISD
# 0           1902                      CAYUGA ISD
# 223        47901                    COMANCHE ISD
