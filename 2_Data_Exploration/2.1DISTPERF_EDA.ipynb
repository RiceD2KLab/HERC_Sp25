# %% [markdown]
# DISTPERF Data Exploration:
# - PERF1 Postsecondary Indicators: College, Career, and Military Readiness (CCMR), TSIA, College Prep

# %% [markdown]
# Importing necesssary packages

# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# Pulling all DISTPERF1 files from 2019-20 --> 2022-23 academic school years

# %%
# Initialize dictionary to store dataframes
dataframes = {}

# Base directory
base_path = r"C:\Users\mmath\OneDrive\Desktop\Capstone\HERC_Sp25\0_Datasets_csv"

# Iterate through years
for year in range(2020, 2024):
    file_names = [
        f"distperf_{year}_clean.csv",
        f"distperf1_{year}_clean.csv",
        f"distperf2_{year}_clean.csv"
    ]
    
    for file_name in file_names:
        file_path = os.path.join(base_path, f"Data{year}", "District", "clean_data", file_name)
        
        if os.path.exists(file_path):  # Check if file exists
            key = f"{file_name.split('.')[0]}"  # Extract filename without extension
            dataframes[key] = pd.read_csv(file_path)  # Read into dictionary

# Print keys to verify
print("Loaded DataFrames:", dataframes.keys())
# Out:
# Loaded DataFrames: dict_keys(['distperf_2020_clean', 'distperf1_2021_clean', 'distperf2_2021_clean', 'distperf1_2022_clean', 'distperf2_2022_clean', 'distperf1_2023_clean', 'distperf2_2023_clean'])

# %% [markdown]
# Creating functions to examine the number of missing values for each column, and dropping columns with >50% missing vlaues.

# %%
def calculate_missing_percentage(df):
    """
    Function to calculate the percentage of missing values in each column of a given dataset.
    
    Parameters:
        df (pd.DataFrame): The dataset as a pandas DataFrame.
    
    Returns:
        pd.Series: A Series with column names as index and percentage of missing values as values.
    """
    missing_percentage = (df.isna().sum() / len(df)) * 100
    missing_percentage = missing_percentage[missing_percentage > 0]  # Only keep columns with missing values
    
    return missing_percentage.sort_values(ascending=False)  # Sort in descending order

def drop_columns(df, threshold=50):
    """
    Function to drop columns with missing values exceeding a specified threshold
    and columns containing 'numerator' or 'denominator' in their names. These columsn are going to be fairly useless for analysis 
    
    Parameters:
        df (pd.DataFrame): The dataset as a pandas DataFrame.
        threshold (float): The percentage threshold for dropping columns.
    
    Returns:
        pd.DataFrame: The dataframe with columns dropped.
    """
    print(f"Original Dataset Shape: {df.shape}")
    missing_percentage = calculate_missing_percentage(df)
    cols_to_drop = set(missing_percentage[missing_percentage >= threshold].index)
    
    # Drop columns containing 'numerator' or 'denominator' (case-insensitive)
    cols_to_drop.update([col for col in df.columns if 'numerator' in col.lower() or 'denominator' in col.lower()])
    
    resulting_df = df.drop(columns=cols_to_drop)
    print(f"Dropped Dataset Shape: {resulting_df.shape}")
    return resulting_df

# %% [markdown]
# Applying dropped datasets logic to create cleaner datasets

# %%
for dataset in dataframes:
    dataframes[dataset] = drop_columns(dataframes[dataset])
# Out:
# Original Dataset Shape: (1202, 4179)
# Dropped Dataset Shape: (1202, 1098)
# Original Dataset Shape: (1204, 2014)
# Dropped Dataset Shape: (1204, 511)
# Original Dataset Shape: (1204, 1300)
# Dropped Dataset Shape: (1204, 398)
# Original Dataset Shape: (1207, 2043)
# Dropped Dataset Shape: (1207, 525)
# Original Dataset Shape: (1207, 1286)
# Dropped Dataset Shape: (1207, 406)
# Original Dataset Shape: (1209, 2012)
# Dropped Dataset Shape: (1209, 502)
# Original Dataset Shape: (1209, 1298)
# Dropped Dataset Shape: (1209, 406)

# %%
distperf1_2023 = dataframes['distperf1_2023_clean']

# Extract relevant columns
all_students_2022 = distperf1_2023['District 2022 College, Career, & Military Ready Graduates: All Students Rate'] / 100
hispanic_2022 = distperf1_2023['District 2022 College, Career, & Military Ready Graduates: Hispanic Rate'] / 100
#all_students_2021 = distperf1_2023['District 2021 College, Career, & Military Ready Graduates: All Students Rate'] / 100
#hispanic_2021 = distperf1_2023['District 2021 College, Career, & Military Ready Graduates: Hispanic Rate'] / 100

# Calculate the absolute difference between all students and Hispanic rates
rate_difference = all_students_2022 - hispanic_2022 #np.abs(all_students_2022 - hispanic_2022)

# Get the top 10 districts with the highest difference
top_10_diff = distperf1_2023.loc[rate_difference.nlargest(10).index, ['DISTNAME']].copy()
top_10_diff['Rate Difference'] = rate_difference.nlargest(10).values

# Sorting for better visualization
top_10_diff = top_10_diff.sort_values(by='Rate Difference', ascending=True)

# Create the bar plot
plt.figure(figsize=(10, 6))
bars = plt.barh(top_10_diff['DISTNAME'], top_10_diff['Rate Difference'], color='skyblue')
plt.xlim(0, max(top_10_diff['Rate Difference']) * 1.15)  # Add 15% padding to the right

# Add labels to the bars
for bar, diff in zip(bars, top_10_diff['Rate Difference']):
    plt.text(bar.get_width() + 0.005, bar.get_y() + bar.get_height()/2, f'{diff:.2%}', va='center')

# Titles and labels
plt.xlabel('CCMR Rate Difference (All Students - Hispanic)')
plt.ylabel('District Name')
plt.title('Top 10 School Districts with Highest CCMR Rate Disparity (2022)')
plt.gca().invert_yaxis()  # Invert y-axis to show highest disparities at the top

# Show plot
plt.show()

# %% [markdown]
# Gathering top 5 and bottom 5 schools in terms of  District 2022 College, Career, & Military Ready Graduates: All Students Rate

# %% [markdown]
# Examining 'District 2022 College, Career, & Military Ready Graduates: All Students Rate'
# * Exploring the distribution of graduation rates and bottom 10 schools by graduation rate

# %%
#Gathering all student rates 
all_students_2022 = distperf1_2023['District 2022 College, Career, & Military Ready Graduates: All Students Rate'] / 100
all_students_2021 = distperf1_2023['District 2021 College, Career, & Military Ready Graduates: All Students Rate'] / 100

#### Creating a histogram of rates 
# Creating the histogram
plt.figure(figsize=(8, 5))
plt.hist(all_students_2022, bins=20, color='skyblue', edgecolor='black', alpha=0.75)

# Titles and labels
plt.xlabel('CCMR Graduation Rate (Proportion)')
plt.ylabel('Frequency')
plt.title('Distribution of CCMR Graduation Rates (2022)')

# Show the grid for better readability
plt.grid(axis='y', linestyle='None', alpha=0.7)

# Display the histogram
plt.show()




### Finding the bottom 10 school districts by CCMR Graduate: All Student Rate 
bottom_10_schools = distperf1_2023.nsmallest(10,
                                         'District 2022 College, Career, & Military Ready Graduates: All Students Rate')[['DISTNAME',
                                                                                                                           'District 2022 College, Career, & Military Ready Graduates: All Students Rate']]
# Creating the bar plot
plt.figure(figsize=(12, 6))
bars = plt.barh(bottom_10_schools['DISTNAME'], bottom_10_schools['District 2022 College, Career, & Military Ready Graduates: All Students Rate'], color='skyblue')
# Adjust x-axis limit to prevent text from falling off
plt.xlim(0, max(bottom_10_schools['District 2022 College, Career, & Military Ready Graduates: All Students Rate']) * 1.15)  # Add 15% padding to the right
# Adding labels to each bar
for bar, rate in zip(bars, bottom_10_schools['District 2022 College, Career, & Military Ready Graduates: All Students Rate']):
    plt.text(bar.get_width() + 1, bar.get_y() + bar.get_height()/2, f'{rate:.1f}%', va='center')

# Titles and labels
plt.xlabel('CCMR Graduate Rate (%)')
plt.ylabel('District Name')
plt.title('Bottom 10 School Districts by CCMR Graduate Rate (2022)')
plt.gca().invert_yaxis()  # Invert y-axis to show lowest rates at the top

# Show plot
plt.show()

# %%
list(dataframes['distperf1_2023_clean'].columns)
# Out:
# ['DISTRICT_id',
#  'District 2022 College, Career, & Military Ready Graduates: All Students Rate',
#  'District 2022 College, Career, & Military Ready Graduates: Hispanic Rate',
#  'District 2022 College, Career, & Military Ready Graduates: White Rate',
#  'District 2022 College, Career, & Military Ready Graduates: Male Rate',
#  'District 2022 College, Career, & Military Ready Graduates: Female Rate',
#  'District 2022 College, Career, & Military Ready Graduates: Econ Disadv Rate',
#  'District 2022 College, Career, & Military Ready Graduates: Special Ed Rate',
#  'District 2022 College, Career, & Military Ready Graduates: At Risk Rate',
#  'District 2021 College, Career, & Military Ready Graduates: All Students Rate',
#  'District 2021 College, Career, & Military Ready Graduates: Hispanic Rate',
#  'District 2021 College, Career, & Military Ready Graduates: White Rate',
#  'District 2021 College, Career, & Military Ready Graduates: Male Rate',
#  'District 2021 College, Career, & Military Ready Graduates: Female Rate',
#  'District 2021 College, Career, & Military Ready Graduates: Econ Disadv Rate',
#  'District 2021 College, Career, & Military Ready Graduates: Special Ed Rate',
#  'District 2021 College, Career, & Military Ready Graduates: At Risk Rate',
#  'District 2022 Associated CCMR: College Ready - All Students Rate',
#  'District 2022 Associated CCMR: College Ready Only - All Students Rate',
#  'District 2022 Associated CCMR: Career/Military Ready Only - All Students Rate',
#  'District 2022 Associated CCMR: College Ready and Career/Military Ready - All Students Rate',
#  'District 2022 Associated CCMR: College Ready - Hispanic Rate',
#  'District 2022 Associated CCMR: College Ready Only - Hispanic Rate',
#  'District 2022 Associated CCMR: Career/Military Ready Only - Hispanic Rate',
#  'District 2022 Associated CCMR: College Ready and Career/Military Ready - Hispanic Rate',
#  'District 2022 Associated CCMR: College Ready - White Rate',
#  'District 2022 Associated CCMR: College Ready Only - White Rate',
#  'District 2022 Associated CCMR: Career/Military Ready Only - White Rate',
#  'District 2022 Associated CCMR: College Ready and Career/Military Ready - White Rate',
#  'District 2022 Associated CCMR: College Ready - Male Rate',
#  'District 2022 Associated CCMR: College Ready Only - Male Rate',
#  'District 2022 Associated CCMR: Career/Military Ready Only - Male Rate',
#  'District 2022 Associated CCMR: College Ready and Career/Military Ready - Male Rate',
#  'District 2022 Associated CCMR: College Ready - Female Rate',
#  'District 2022 Associated CCMR: College Ready Only - Female Rate',
#  'District 2022 Associated CCMR: Career/Military Ready Only - Female Rate',
#  'District 2022 Associated CCMR: College Ready and Career/Military Ready - Female Rate',
#  'District 2022 Associated CCMR: College Ready - Econ Disadv Rate',
#  'District 2022 Associated CCMR: College Ready Only - Econ Disadv Rate',
#  'District 2022 Associated CCMR: Career/Military Ready Only - Econ Disadv Rate',
#  'District 2022 Associated CCMR: College Ready and Career/Military Ready - Econ Disadv Rate',
#  'District 2022 Associated CCMR: College Ready - Special Ed Rate',
#  'District 2022 Associated CCMR: College Ready Only - Special Ed Rate',
#  'District 2022 Associated CCMR: Career/Military Ready Only - Special Ed Rate',
#  'District 2022 Associated CCMR: College Ready and Career/Military Ready - Special Ed Rate',
#  'District 2022 Associated CCMR: College Ready - At Risk Rate',
#  'District 2022 Associated CCMR: College Ready Only - At Risk Rate',
#  'District 2022 Associated CCMR: Career/Military Ready Only - At Risk Rate',
#  'District 2022 Associated CCMR: College Ready and Career/Military Ready - At Risk Rate',
#  'District 2021 Associated CCMR: College Ready - All Students Rate',
#  'District 2021 Associated CCMR: College Ready Only - All Students Rate',
#  'District 2021 Associated CCMR: Career/Military Ready Only - All Students Rate',
#  'District 2021 Associated CCMR: College Ready and Career/Military Ready - All Students Rate',
#  'District 2021 Associated CCMR: College Ready - Hispanic Rate',
#  'District 2021 Associated CCMR: College Ready Only - Hispanic Rate',
#  'District 2021 Associated CCMR: Career/Military Ready Only - Hispanic Rate',
#  'District 2021 Associated CCMR: College Ready and Career/Military Ready - Hispanic Rate',
#  'District 2021 Associated CCMR: College Ready - White Rate',
#  'District 2021 Associated CCMR: College Ready Only - White Rate',
#  'District 2021 Associated CCMR: Career/Military Ready Only - White Rate',
#  'District 2021 Associated CCMR: College Ready and Career/Military Ready - White Rate',
#  'District 2021 Associated CCMR: College Ready - Male Rate',
#  'District 2021 Associated CCMR: College Ready Only - Male Rate',
#  'District 2021 Associated CCMR: Career/Military Ready Only - Male Rate',
#  'District 2021 Associated CCMR: College Ready and Career/Military Ready - Male Rate',
#  'District 2021 Associated CCMR: College Ready - Female Rate',
#  'District 2021 Associated CCMR: College Ready Only - Female Rate',
#  'District 2021 Associated CCMR: Career/Military Ready Only - Female Rate',
#  'District 2021 Associated CCMR: College Ready and Career/Military Ready - Female Rate',
#  'District 2021 Associated CCMR: College Ready - Econ Disadv Rate',
#  'District 2021 Associated CCMR: College Ready Only - Econ Disadv Rate',
#  'District 2021 Associated CCMR: Career/Military Ready Only - Econ Disadv Rate',
#  'District 2021 Associated CCMR: College Ready and Career/Military Ready - Econ Disadv Rate',
#  'District 2021 Associated CCMR: College Ready - Special Ed Rate',
#  'District 2021 Associated CCMR: College Ready Only - Special Ed Rate',
#  'District 2021 Associated CCMR: Career/Military Ready Only - Special Ed Rate',
#  'District 2021 Associated CCMR: College Ready and Career/Military Ready - Special Ed Rate',
#  'District 2021 Associated CCMR: College Ready - At Risk Rate',
#  'District 2021 Associated CCMR: College Ready Only - At Risk Rate',
#  'District 2021 Associated CCMR: Career/Military Ready Only - At Risk Rate',
#  'District 2021 Associated CCMR: College Ready and Career/Military Ready - At Risk Rate',
#  'District 2022 TSI Criteria Graduates: All Students Mathematics Rate',
#  'District 2022 TSI Criteria Graduates: All Students Reading Rate',
#  'District 2022 TSI Criteria Graduates: All Students Both Rate',
#  'District 2022 TSI Criteria Graduates: All Students Either Rate',
#  'District 2022 TSI Criteria Graduates: Hispanic Mathematics Rate',
#  'District 2022 TSI Criteria Graduates: Hispanic Reading Rate',
#  'District 2022 TSI Criteria Graduates: Hispanic Both Rate',
#  'District 2022 TSI Criteria Graduates: Hispanic Either Rate',
#  'District 2022 TSI Criteria Graduates: White Mathematics Rate',
#  'District 2022 TSI Criteria Graduates: White Reading Rate',
#  'District 2022 TSI Criteria Graduates: White Both Rate',
#  'District 2022 TSI Criteria Graduates: White Either Rate',
#  'District 2022 TSI Criteria Graduates: Male Mathematics Rate',
#  'District 2022 TSI Criteria Graduates: Male Reading Rate',
#  'District 2022 TSI Criteria Graduates: Male Both Rate',
#  'District 2022 TSI Criteria Graduates: Male Either Rate',
#  'District 2022 TSI Criteria Graduates: Female Mathematics Rate',
#  'District 2022 TSI Criteria Graduates: Female Reading Rate',
#  'District 2022 TSI Criteria Graduates: Female Both Rate',
#  'District 2022 TSI Criteria Graduates: Female Either Rate',
#  'District 2022 TSI Criteria Graduates: Special Ed Mathematics Rate',
#  'District 2022 TSI Criteria Graduates: Special Ed Reading Rate',
#  'District 2022 TSI Criteria Graduates: Special Ed Both Rate',
#  'District 2022 TSI Criteria Graduates: Special Ed Either Rate',
#  'District 2022 TSI Criteria Graduates: Econ Disadv Mathematics Rate',
#  'District 2022 TSI Criteria Graduates: Econ Disadv Reading Rate',
#  'District 2022 TSI Criteria Graduates: Econ Disadv Both Rate',
#  'District 2022 TSI Criteria Graduates: Econ Disadv Either Rate',
#  'District 2022 TSI Criteria Graduates: At Risk Mathematics Rate',
#  'District 2022 TSI Criteria Graduates: At Risk Reading Rate',
#  'District 2022 TSI Criteria Graduates: At Risk Both Rate',
#  'District 2022 TSI Criteria Graduates: At Risk Either Rate',
#  'District 2021 TSI Criteria Graduates: All Students Mathematics Rate',
#  'District 2021 TSI Criteria Graduates: All Students Reading Rate',
#  'District 2021 TSI Criteria Graduates: All Students Both Rate',
#  'District 2021 TSI Criteria Graduates: All Students Either Rate',
#  'District 2021 TSI Criteria Graduates: Hispanic Mathematics Rate',
#  'District 2021 TSI Criteria Graduates: Hispanic Reading Rate',
#  'District 2021 TSI Criteria Graduates: Hispanic Both Rate',
#  'District 2021 TSI Criteria Graduates: Hispanic Either Rate',
#  'District 2021 TSI Criteria Graduates: White Mathematics Rate',
#  'District 2021 TSI Criteria Graduates: White Reading Rate',
#  'District 2021 TSI Criteria Graduates: White Both Rate',
#  'District 2021 TSI Criteria Graduates: White Either Rate',
#  'District 2021 TSI Criteria Graduates: Male Mathematics Rate',
#  'District 2021 TSI Criteria Graduates: Male Reading Rate',
#  'District 2021 TSI Criteria Graduates: Male Both Rate',
#  'District 2021 TSI Criteria Graduates: Male Either Rate',
#  'District 2021 TSI Criteria Graduates: Female Mathematics Rate',
#  'District 2021 TSI Criteria Graduates: Female Reading Rate',
#  'District 2021 TSI Criteria Graduates: Female Both Rate',
#  'District 2021 TSI Criteria Graduates: Female Either Rate',
#  'District 2021 TSI Criteria Graduates: Special Ed Mathematics Rate',
#  'District 2021 TSI Criteria Graduates: Special Ed Reading Rate',
#  'District 2021 TSI Criteria Graduates: Special Ed Both Rate',
#  'District 2021 TSI Criteria Graduates: Special Ed Either Rate',
#  'District 2021 TSI Criteria Graduates: Econ Disadv Mathematics Rate',
#  'District 2021 TSI Criteria Graduates: Econ Disadv Reading Rate',
#  'District 2021 TSI Criteria Graduates: Econ Disadv Both Rate',
#  'District 2021 TSI Criteria Graduates: Econ Disadv Either Rate',
#  'District 2021 TSI Criteria Graduates: At Risk Mathematics Rate',
#  'District 2021 TSI Criteria Graduates: At Risk Reading Rate',
#  'District 2021 TSI Criteria Graduates: At Risk Both Rate',
#  'District 2021 TSI Criteria Graduates: At Risk Either Rate',
#  'District 2022 Associated CCMR: Associate Degree and Career/Military Ready - All Students Rate',
#  'District 2022 Associated CCMR: Associate Degree but not Career/Military Ready - All Students Rate',
#  'District 2022 Associated CCMR: Dual Course Credits or OnRamps Course Credits - All Students Rate',
#  'District 2022 Associated CCMR: Industry-Based Certification or Level I/II Certificate - All Students Rate',
#  'District 2022 Associated CCMR: Associate Degree and Career/Military Ready - Hispanic Rate',
#  'District 2022 Associated CCMR: Associate Degree but not Career/Military Ready - Hispanic Rate',
#  'District 2022 Associated CCMR: Dual Course Credits or OnRamps Course Credits - Hispanic Rate',
#  'District 2022 Associated CCMR: Industry-Based Certification or Level I/II Certificate - Hispanic Rate',
#  'District 2022 Associated CCMR: Associate Degree and Career/Military Ready - White Rate',
#  'District 2022 Associated CCMR: Associate Degree but not Career/Military Ready - White Rate',
#  'District 2022 Associated CCMR: Dual Course Credits or OnRamps Course Credits - White Rate',
#  'District 2022 Associated CCMR: Industry-Based Certification or Level I/II Certificate - White Rate',
#  'District 2022 Associated CCMR: Associate Degree and Career/Military Ready - Male Rate',
#  'District 2022 Associated CCMR: Associate Degree but not Career/Military Ready - Male Rate',
#  'District 2022 Associated CCMR: Dual Course Credits or OnRamps Course Credits - Male Rate',
#  'District 2022 Associated CCMR: Industry-Based Certification or Level I/II Certificate - Male Rate',
#  'District 2022 Associated CCMR: Associate Degree and Career/Military Ready - Female Rate',
#  'District 2022 Associated CCMR: Associate Degree but not Career/Military Ready - Female Rate',
#  'District 2022 Associated CCMR: Dual Course Credits or OnRamps Course Credits - Female Rate',
#  'District 2022 Associated CCMR: Industry-Based Certification or Level I/II Certificate - Female Rate',
#  'District 2022 Associated CCMR: Associate Degree and Career/Military Ready - Econ Disadv Rate',
#  'District 2022 Associated CCMR: Associate Degree but not Career/Military Ready - Econ Disadv Rate',
#  'District 2022 Associated CCMR: Dual Course Credits or OnRamps Course Credits - Econ Disadv Rate',
#  'District 2022 Associated CCMR: Industry-Based Certification or Level I/II Certificate - Econ Disadv Rate',
#  'District 2022 Associated CCMR: Associate Degree and Career/Military Ready - Special Ed Rate',
#  'District 2022 Associated CCMR: Associate Degree but not Career/Military Ready - Special Ed Rate',
#  'District 2022 Associated CCMR: Dual Course Credits or OnRamps Course Credits - Special Ed Rate',
#  'District 2022 Associated CCMR: Industry-Based Certification or Level I/II Certificate - Special Ed Rate',
#  'District 2022 Associated CCMR: Associate Degree and Career/Military Ready - At Risk Rate',
#  'District 2022 Associated CCMR: Associate Degree but not Career/Military Ready - At Risk Rate',
#  'District 2022 Associated CCMR: Dual Course Credits or OnRamps Course Credits - At Risk Rate',
#  'District 2022 Associated CCMR: Industry-Based Certification or Level I/II Certificate - At Risk Rate',
#  'District 2021 Associated CCMR: Associate Degree and Career/Military Ready - All Students Rate',
#  'District 2021 Associated CCMR: Associate Degree but not Career/Military Ready - All Students Rate',
#  'District 2021 Associated CCMR: Dual Course Credits or OnRamps Course Credits - All Students Rate',
#  'District 2021 Associated CCMR: Industry-Based Certification or Level I/II Certificate - All Students Rate',
#  'District 2021 Associated CCMR: Associate Degree and Career/Military Ready - Hispanic Rate',
#  'District 2021 Associated CCMR: Associate Degree but not Career/Military Ready - Hispanic Rate',
#  'District 2021 Associated CCMR: Dual Course Credits or OnRamps Course Credits - Hispanic Rate',
#  'District 2021 Associated CCMR: Industry-Based Certification or Level I/II Certificate - Hispanic Rate',
#  'District 2021 Associated CCMR: Associate Degree and Career/Military Ready - White Rate',
#  'District 2021 Associated CCMR: Associate Degree but not Career/Military Ready - White Rate',
#  'District 2021 Associated CCMR: Dual Course Credits or OnRamps Course Credits - White Rate',
#  'District 2021 Associated CCMR: Industry-Based Certification or Level I/II Certificate - White Rate',
#  'District 2021 Associated CCMR: Associate Degree and Career/Military Ready - Male Rate',
#  'District 2021 Associated CCMR: Associate Degree but not Career/Military Ready - Male Rate',
#  'District 2021 Associated CCMR: Dual Course Credits or OnRamps Course Credits - Male Rate',
#  'District 2021 Associated CCMR: Industry-Based Certification or Level I/II Certificate - Male Rate',
#  'District 2021 Associated CCMR: Associate Degree and Career/Military Ready - Female Rate',
#  'District 2021 Associated CCMR: Associate Degree but not Career/Military Ready - Female Rate',
#  'District 2021 Associated CCMR: Dual Course Credits or OnRamps Course Credits - Female Rate',
#  'District 2021 Associated CCMR: Industry-Based Certification or Level I/II Certificate - Female Rate',
#  'District 2021 Associated CCMR: Associate Degree and Career/Military Ready - Econ Disadv Rate',
#  'District 2021 Associated CCMR: Associate Degree but not Career/Military Ready - Econ Disadv Rate',
#  'District 2021 Associated CCMR: Dual Course Credits or OnRamps Course Credits - Econ Disadv Rate',
#  'District 2021 Associated CCMR: Industry-Based Certification or Level I/II Certificate - Econ Disadv Rate',
#  'District 2021 Associated CCMR: Associate Degree and Career/Military Ready - Special Ed Rate',
#  'District 2021 Associated CCMR: Associate Degree but not Career/Military Ready - Special Ed Rate',
#  'District 2021 Associated CCMR: Dual Course Credits or OnRamps Course Credits - Special Ed Rate',
#  'District 2021 Associated CCMR: Industry-Based Certification or Level I/II Certificate - Special Ed Rate',
#  'District 2021 Associated CCMR: Associate Degree and Career/Military Ready - At Risk Rate',
#  'District 2021 Associated CCMR: Associate Degree but not Career/Military Ready - At Risk Rate',
#  'District 2021 Associated CCMR: Dual Course Credits or OnRamps Course Credits - At Risk Rate',
#  'District 2021 Associated CCMR: Industry-Based Certification or Level I/II Certificate - At Risk Rate',
#  'District 2022 Dual Credit Graduates: 3 Hrs ELA or Math, or 9 Hrs Any Subject: All Students Rate',
#  'District 2022 Dual Credit Graduates: 3 Hrs ELA or Math, or 9 Hrs Any Subject: Hispanic Rate',
#  'District 2022 Dual Credit Graduates: 3 Hrs ELA or Math, or 9 Hrs Any Subject: White Rate',
#  'District 2022 Dual Credit Graduates: 3 Hrs ELA or Math, or 9 Hrs Any Subject: Male Rate',
#  'District 2022 Dual Credit Graduates: 3 Hrs ELA or Math, or 9 Hrs Any Subject: Female Rate',
#  'District 2022 Dual Credit Graduates: 3 Hrs ELA or Math, or 9 Hrs Any Subject: Econ Disadv Rate',
#  'District 2022 Dual Credit Graduates: 3 Hrs ELA or Math, or 9 Hrs Any Subject: Special Ed Rate',
#  'District 2022 Dual Credit Graduates: 3 Hrs ELA or Math, or 9 Hrs Any Subject: At Risk Rate',
#  'District 2021 Dual Credit Graduates: 3 Hrs ELA or Math, or 9 Hrs Any Subject: All Students Rate',
#  'District 2021 Dual Credit Graduates: 3 Hrs ELA or Math, or 9 Hrs Any Subject: Hispanic Rate',
#  'District 2021 Dual Credit Graduates: 3 Hrs ELA or Math, or 9 Hrs Any Subject: White Rate',
#  'District 2021 Dual Credit Graduates: 3 Hrs ELA or Math, or 9 Hrs Any Subject: Male Rate',
#  'District 2021 Dual Credit Graduates: 3 Hrs ELA or Math, or 9 Hrs Any Subject: Female Rate',
#  'District 2021 Dual Credit Graduates: 3 Hrs ELA or Math, or 9 Hrs Any Subject: Econ Disadv Rate',
#  'District 2021 Dual Credit Graduates: 3 Hrs ELA or Math, or 9 Hrs Any Subject: Special Ed Rate',
#  'District 2021 Dual Credit Graduates: 3 Hrs ELA or Math, or 9 Hrs Any Subject: At Risk Rate',
#  'District 2022 AP/IB Met Criteria in Any Subject Graduates: All Students Rate',
#  'District 2022 AP/IB Met Criteria in Any Subject Graduates: Hispanic Rate',
#  'District 2022 AP/IB Met Criteria in Any Subject Graduates: White Rate',
#  'District 2022 AP/IB Met Criteria in Any Subject Graduates: Male Rate',
#  'District 2022 AP/IB Met Criteria in Any Subject Graduates: Female Rate',
#  'District 2022 AP/IB Met Criteria in Any Subject Graduates: Econ Disadv Rate',
#  'District 2022 AP/IB Met Criteria in Any Subject Graduates: Special Ed Rate',
#  'District 2022 AP/IB Met Criteria in Any Subject Graduates: At Risk Rate',
#  'District 2021 AP/IB Met Criteria in Any Subject Graduates: All Students Rate',
#  'District 2021 AP/IB Met Criteria in Any Subject Graduates: Hispanic Rate',
#  'District 2021 AP/IB Met Criteria in Any Subject Graduates: White Rate',
#  'District 2021 AP/IB Met Criteria in Any Subject Graduates: Male Rate',
#  'District 2021 AP/IB Met Criteria in Any Subject Graduates: Female Rate',
#  'District 2021 AP/IB Met Criteria in Any Subject Graduates: Econ Disadv Rate',
#  'District 2021 AP/IB Met Criteria in Any Subject Graduates: Special Ed Rate',
#  'District 2021 AP/IB Met Criteria in Any Subject Graduates: At Risk Rate',
#  'District 2022 Associate Degree Graduates: All Students Rate',
#  'District 2022 Associate Degree Graduates: Hispanic Rate',
#  'District 2022 Associate Degree Graduates: White Rate',
#  'District 2022 Associate Degree Graduates: Male Rate',
#  'District 2022 Associate Degree Graduates: Female Rate',
#  'District 2022 Associate Degree Graduates: Econ Disadv Rate',
#  'District 2022 Associate Degree Graduates: Special Ed Rate',
#  'District 2022 Associate Degree Graduates: At Risk Rate',
#  'District 2021 Associate Degree Graduates: All Students Rate',
#  'District 2021 Associate Degree Graduates: Hispanic Rate',
#  'District 2021 Associate Degree Graduates: White Rate',
#  'District 2021 Associate Degree Graduates: Male Rate',
#  'District 2021 Associate Degree Graduates: Female Rate',
#  'District 2021 Associate Degree Graduates: Econ Disadv Rate',
#  'District 2021 Associate Degree Graduates: Special Ed Rate',
#  'District 2021 Associate Degree Graduates: At Risk Rate',
#  'District 2022 Completion of OnRamps Course Graduates: All Students Rate',
#  'District 2022 Completion of OnRamps Course Graduates: Hispanic Rate',
#  'District 2022 Completion of OnRamps Course Graduates: White Rate',
#  'District 2022 Completion of OnRamps Course Graduates: Male Rate',
#  'District 2022 Completion of OnRamps Course Graduates: Female Rate',
#  'District 2022 Completion of OnRamps Course Graduates: Econ Disadv Rate',
#  'District 2022 Completion of OnRamps Course Graduates: Special Ed Rate',
#  'District 2022 Completion of OnRamps Course Graduates: At Risk Rate',
#  'District 2021 Completion of OnRamps Course Graduates: All Students Rate',
#  'District 2021 Completion of OnRamps Course Graduates: Hispanic Rate',
#  'District 2021 Completion of OnRamps Course Graduates: White Rate',
#  'District 2021 Completion of OnRamps Course Graduates: Male Rate',
#  'District 2021 Completion of OnRamps Course Graduates: Female Rate',
#  'District 2021 Completion of OnRamps Course Graduates: Econ Disadv Rate',
#  'District 2021 Completion of OnRamps Course Graduates: Special Ed Rate',
#  'District 2021 Completion of OnRamps Course Graduates: At Risk Rate',
#  'District 2022 Associated CCMR: Career/Military Ready - All Students Rate',
#  'District 2022 Associated CCMR: Career/Military Ready - Hispanic Rate',
#  'District 2022 Associated CCMR: Career/Military Ready - White Rate',
#  'District 2022 Associated CCMR: Career/Military Ready - Male Rate',
#  'District 2022 Associated CCMR: Career/Military Ready - Female Rate',
#  'District 2022 Associated CCMR: Career/Military Ready - Econ Disadv Rate',
#  'District 2022 Associated CCMR: Career/Military Ready - Special Ed Rate',
#  'District 2022 Associated CCMR: Career/Military Ready - At Risk Rate',
#  'District 2021 Associated CCMR: Career/Military Ready - All Students Rate',
#  'District 2021 Associated CCMR: Career/Military Ready - Hispanic Rate',
#  'District 2021 Associated CCMR: Career/Military Ready - White Rate',
#  'District 2021 Associated CCMR: Career/Military Ready - Male Rate',
#  'District 2021 Associated CCMR: Career/Military Ready - Female Rate',
#  'District 2021 Associated CCMR: Career/Military Ready - Econ Disadv Rate',
#  'District 2021 Associated CCMR: Career/Military Ready - Special Ed Rate',
#  'District 2021 Associated CCMR: Career/Military Ready - At Risk Rate',
#  'District 2022 Industry-Based Certification Graduates: All Students Rate',
#  'District 2022 Industry-Based Certification Graduates: Hispanic Rate',
#  'District 2022 Industry-Based Certification Graduates: White Rate',
#  'District 2022 Industry-Based Certification Graduates: Male Rate',
#  'District 2022 Industry-Based Certification Graduates: Female Rate',
#  'District 2022 Industry-Based Certification Graduates: Econ Disadv Rate',
#  'District 2022 Industry-Based Certification Graduates: Special Ed Rate',
#  'District 2022 Industry-Based Certification Graduates: At Risk Rate',
#  'District 2021 Industry-Based Certification Graduates: All Students Rate',
#  'District 2021 Industry-Based Certification Graduates: Hispanic Rate',
#  'District 2021 Industry-Based Certification Graduates: White Rate',
#  'District 2021 Industry-Based Certification Graduates: Male Rate',
#  'District 2021 Industry-Based Certification Graduates: Female Rate',
#  'District 2021 Industry-Based Certification Graduates: Econ Disadv Rate',
#  'District 2021 Industry-Based Certification Graduates: Special Ed Rate',
#  'District 2021 Industry-Based Certification Graduates: At Risk Rate',
#  'District 2022 Completed IEP & Workforce Readiness Graduates: All Students Rate',
#  'District 2022 Completed IEP & Workforce Readiness Graduates: Hispanic Rate',
#  'District 2022 Completed IEP & Workforce Readiness Graduates: White Rate',
#  'District 2022 Completed IEP & Workforce Readiness Graduates: Male Rate',
#  'District 2022 Completed IEP & Workforce Readiness Graduates: Female Rate',
#  'District 2022 Completed IEP & Workforce Readiness Graduates: Econ Disadv Rate',
#  'District 2022 Completed IEP & Workforce Readiness Graduates: Special Ed Rate',
#  'District 2022 Completed IEP & Workforce Readiness Graduates: At Risk Rate',
#  'District 2021 Completed IEP & Workforce Readiness Graduates: All Students Rate',
#  'District 2021 Completed IEP & Workforce Readiness Graduates: Hispanic Rate',
#  'District 2021 Completed IEP & Workforce Readiness Graduates: White Rate',
#  'District 2021 Completed IEP & Workforce Readiness Graduates: Male Rate',
#  'District 2021 Completed IEP & Workforce Readiness Graduates: Female Rate',
#  'District 2021 Completed IEP & Workforce Readiness Graduates: Econ Disadv Rate',
#  'District 2021 Completed IEP & Workforce Readiness Graduates: Special Ed Rate',
#  'District 2021 Completed IEP & Workforce Readiness Graduates: At Risk Rate',
#  'District 2022 Special Ed Graduates with Advanced Diploma Plan: All Students Rate',
#  'District 2022 Special Ed Graduates with Advanced Diploma Plan: Hispanic Rate',
#  'District 2022 Special Ed Graduates with Advanced Diploma Plan: White Rate',
#  'District 2022 Special Ed Graduates with Advanced Diploma Plan: Male Rate',
#  'District 2022 Special Ed Graduates with Advanced Diploma Plan: Female Rate',
#  'District 2022 Special Ed Graduates with Advanced Diploma Plan: Econ Disadv Rate',
#  'District 2022 Special Ed Graduates with Advanced Diploma Plan: Special Ed Rate',
#  'District 2022 Special Ed Graduates with Advanced Diploma Plan: At Risk Rate',
#  'District 2021 Special Ed Graduates with Advanced Diploma Plan: All Students Rate',
#  'District 2021 Special Ed Graduates with Advanced Diploma Plan: Hispanic Rate',
#  'District 2021 Special Ed Graduates with Advanced Diploma Plan: White Rate',
#  'District 2021 Special Ed Graduates with Advanced Diploma Plan: Male Rate',
#  'District 2021 Special Ed Graduates with Advanced Diploma Plan: Female Rate',
#  'District 2021 Special Ed Graduates with Advanced Diploma Plan: Econ Disadv Rate',
#  'District 2021 Special Ed Graduates with Advanced Diploma Plan: Special Ed Rate',
#  'District 2021 Special Ed Graduates with Advanced Diploma Plan: At Risk Rate',
#  'District 2022 Earn Certificate Graduates: All Students (Level I or II) Rate',
#  'District 2022 Earn Certificate Graduates: Hispanic (Level I or II) Rate',
#  'District 2022 Earn Certificate Graduates: White (Level I or II) Rate',
#  'District 2022 Earn Certificate Graduates: Male (Level I or II) Rate',
#  'District 2022 Earn Certificate Graduates: Female (Level I or II) Rate',
#  'District 2022 Earn Certificate Graduates: Econ Disadv (Level I or II) Rate',
#  'District 2022 Earn Certificate Graduates: Special Ed (Level I or II) Rate',
#  'District 2022 Earn Certificate Graduates: At Risk (Level I or II) Rate',
#  'District 2021 Earn Certificate Graduates: All Students (Level I or II) Rate',
#  'District 2021 Earn Certificate Graduates: Hispanic (Level I or II) Rate',
#  'District 2021 Earn Certificate Graduates: White (Level I or II) Rate',
#  'District 2021 Earn Certificate Graduates: Male (Level I or II) Rate',
#  'District 2021 Earn Certificate Graduates: Female (Level I or II) Rate',
#  'District 2021 Earn Certificate Graduates: Econ Disadv (Level I or II) Rate',
#  'District 2021 Earn Certificate Graduates: Special Ed (Level I or II) Rate',
#  'District 2021 Earn Certificate Graduates: At Risk (Level I or II) Rate',
#  'District 2022 Texas Success Initiative Assessment (TSIA): All Students ELAR Rate',
#  'District 2022 Texas Success Initiative Assessment (TSIA): All Students Math Rate',
#  'District 2022 Texas Success Initiative Assessment (TSIA): All Students ELAR & Math Rate',
#  'District 2022 Texas Success Initiative Assessment (TSIA): All Students Tested Rate',
#  'District 2022 Texas Success Initiative Assessment (TSIA): All Students TSIA1 ELAR Average Score',
#  'District 2022 Texas Success Initiative Assessment (TSIA): All Students TSIA1 Math Average Score',
#  'District 2022 Texas Success Initiative Assessment (TSIA): Hispanic ELAR Rate',
#  'District 2022 Texas Success Initiative Assessment (TSIA): Hispanic Math Rate',
#  'District 2022 Texas Success Initiative Assessment (TSIA): Hispanic ELAR & Math Rate',
#  'District 2022 Texas Success Initiative Assessment (TSIA): Hispanic Tested Rate',
#  'District 2022 Texas Success Initiative Assessment (TSIA): Hispanic TSIA1 ELAR Average Score',
#  'District 2022 Texas Success Initiative Assessment (TSIA): Hispanic TSIA1 Math Average Score',
#  'District 2022 Texas Success Initiative Assessment (TSIA): White ELAR Rate',
#  'District 2022 Texas Success Initiative Assessment (TSIA): White Math Rate',
#  'District 2022 Texas Success Initiative Assessment (TSIA): White ELAR & Math Rate',
#  'District 2022 Texas Success Initiative Assessment (TSIA): White Tested Rate',
#  'District 2022 Texas Success Initiative Assessment (TSIA): White TSIA1 ELAR Average Score',
#  'District 2022 Texas Success Initiative Assessment (TSIA): White TSIA1 Math Average Score',
#  'District 2022 Texas Success Initiative Assessment (TSIA): Male ELAR Rate',
#  'District 2022 Texas Success Initiative Assessment (TSIA): Male Math Rate',
#  'District 2022 Texas Success Initiative Assessment (TSIA): Male ELAR & Math Rate',
#  'District 2022 Texas Success Initiative Assessment (TSIA): Male Tested Rate',
#  'District 2022 Texas Success Initiative Assessment (TSIA): Male TSIA1 ELAR Average Score',
#  'District 2022 Texas Success Initiative Assessment (TSIA): Male TSIA1 Math Average Score',
#  'District 2022 Texas Success Initiative Assessment (TSIA): Female ELAR Rate',
#  'District 2022 Texas Success Initiative Assessment (TSIA): Female Math Rate',
#  'District 2022 Texas Success Initiative Assessment (TSIA): Female ELAR & Math Rate',
#  'District 2022 Texas Success Initiative Assessment (TSIA): Female Tested Rate',
#  'District 2022 Texas Success Initiative Assessment (TSIA): Female TSIA1 ELAR Average Score',
#  'District 2022 Texas Success Initiative Assessment (TSIA): Female TSIA1 Math Average Score',
#  'District 2022 Texas Success Initiative Assessment (TSIA): Econ Disadv ELAR Rate',
#  'District 2022 Texas Success Initiative Assessment (TSIA): Econ Disadv Math Rate',
#  'District 2022 Texas Success Initiative Assessment (TSIA): Econ Disadv ELAR & Math Rate',
#  'District 2022 Texas Success Initiative Assessment (TSIA): Econ Disadv Tested Rate',
#  'District 2022 Texas Success Initiative Assessment (TSIA): Econ Disadv TSIA1 ELAR Average Score',
#  'District 2022 Texas Success Initiative Assessment (TSIA): Econ Disadv TSIA1 Math Average Score',
#  'District 2022 Texas Success Initiative Assessment (TSIA): Special Ed ELAR Rate',
#  'District 2022 Texas Success Initiative Assessment (TSIA): Special Ed Math Rate',
#  'District 2022 Texas Success Initiative Assessment (TSIA): Special Ed ELAR & Math Rate',
#  'District 2022 Texas Success Initiative Assessment (TSIA): Special Ed Tested Rate',
#  'District 2022 Texas Success Initiative Assessment (TSIA): At Risk ELAR Rate',
#  'District 2022 Texas Success Initiative Assessment (TSIA): At Risk Math Rate',
#  'District 2022 Texas Success Initiative Assessment (TSIA): At Risk ELAR & Math Rate',
#  'District 2022 Texas Success Initiative Assessment (TSIA): At Risk Tested Rate',
#  'District 2022 Texas Success Initiative Assessment (TSIA): At Risk TSIA1 ELAR Average Score',
#  'District 2022 Texas Success Initiative Assessment (TSIA): At Risk TSIA1 Math Average Score',
#  'District 2021 Texas Success Initiative Assessment (TSIA): All Students ELAR Rate',
#  'District 2021 Texas Success Initiative Assessment (TSIA): All Students Math Rate',
#  'District 2021 Texas Success Initiative Assessment (TSIA): All Students ELAR & Math Rate',
#  'District 2021 Texas Success Initiative Assessment (TSIA): All Students Tested Rate',
#  'District 2021 Texas Success Initiative Assessment (TSIA): All Students TSIA1 ELAR Average Score',
#  'District 2021 Texas Success Initiative Assessment (TSIA): All Students TSIA1 Math Average Score',
#  'District 2021 Texas Success Initiative Assessment (TSIA): Hispanic ELAR Rate',
#  'District 2021 Texas Success Initiative Assessment (TSIA): Hispanic Math Rate',
#  'District 2021 Texas Success Initiative Assessment (TSIA): Hispanic ELAR & Math Rate',
#  'District 2021 Texas Success Initiative Assessment (TSIA): Hispanic Tested Rate',
#  'District 2021 Texas Success Initiative Assessment (TSIA): Hispanic TSIA1 ELAR Average Score',
#  'District 2021 Texas Success Initiative Assessment (TSIA): Hispanic TSIA1 Math Average Score',
#  'District 2021 Texas Success Initiative Assessment (TSIA): White ELAR Rate',
#  'District 2021 Texas Success Initiative Assessment (TSIA): White Math Rate',
#  'District 2021 Texas Success Initiative Assessment (TSIA): White ELAR & Math Rate',
#  'District 2021 Texas Success Initiative Assessment (TSIA): White Tested Rate',
#  'District 2021 Texas Success Initiative Assessment (TSIA): White TSIA1 ELAR Average Score',
#  'District 2021 Texas Success Initiative Assessment (TSIA): White TSIA1 Math Average Score',
#  'District 2021 Texas Success Initiative Assessment (TSIA): Male ELAR Rate',
#  'District 2021 Texas Success Initiative Assessment (TSIA): Male Math Rate',
#  'District 2021 Texas Success Initiative Assessment (TSIA): Male ELAR & Math Rate',
#  'District 2021 Texas Success Initiative Assessment (TSIA): Male Tested Rate',
#  'District 2021 Texas Success Initiative Assessment (TSIA): Male TSIA1 ELAR Average Score',
#  'District 2021 Texas Success Initiative Assessment (TSIA): Male TSIA1 Math Average Score',
#  'District 2021 Texas Success Initiative Assessment (TSIA): Female ELAR Rate',
#  'District 2021 Texas Success Initiative Assessment (TSIA): Female Math Rate',
#  'District 2021 Texas Success Initiative Assessment (TSIA): Female ELAR & Math Rate',
#  'District 2021 Texas Success Initiative Assessment (TSIA): Female Tested Rate',
#  'District 2021 Texas Success Initiative Assessment (TSIA): Female TSIA1 ELAR Average Score',
#  'District 2021 Texas Success Initiative Assessment (TSIA): Female TSIA1 Math Average Score',
#  'District 2021 Texas Success Initiative Assessment (TSIA): Econ Disadv ELAR Rate',
#  'District 2021 Texas Success Initiative Assessment (TSIA): Econ Disadv Math Rate',
#  'District 2021 Texas Success Initiative Assessment (TSIA): Econ Disadv ELAR & Math Rate',
#  'District 2021 Texas Success Initiative Assessment (TSIA): Econ Disadv Tested Rate',
#  'District 2021 Texas Success Initiative Assessment (TSIA): Econ Disadv TSIA1 ELAR Average Score',
#  'District 2021 Texas Success Initiative Assessment (TSIA): Econ Disadv TSIA1 Math Average Score',
#  'District 2021 Texas Success Initiative Assessment (TSIA): Special Ed ELAR Rate',
#  'District 2021 Texas Success Initiative Assessment (TSIA): Special Ed Math Rate',
#  'District 2021 Texas Success Initiative Assessment (TSIA): Special Ed ELAR & Math Rate',
#  'District 2021 Texas Success Initiative Assessment (TSIA): Special Ed Tested Rate',
#  'District 2021 Texas Success Initiative Assessment (TSIA): Special Ed TSIA1 ELAR Average Score',
#  'District 2021 Texas Success Initiative Assessment (TSIA): At Risk ELAR Rate',
#  'District 2021 Texas Success Initiative Assessment (TSIA): At Risk Math Rate',
#  'District 2021 Texas Success Initiative Assessment (TSIA): At Risk ELAR & Math Rate',
#  'District 2021 Texas Success Initiative Assessment (TSIA): At Risk Tested Rate',
#  'District 2021 Texas Success Initiative Assessment (TSIA): At Risk TSIA1 ELAR Average Score',
#  'District 2021 Texas Success Initiative Assessment (TSIA): At Risk TSIA1 Math Average Score',
#  'District 2022 Completion of College Preparation Graduates: All Students ELA Rate',
#  'District 2022 Completion of College Preparation Graduates: All Students Math Rate',
#  'District 2022 Completion of College Preparation Graduates: All Students ELA & Math Rate',
#  'District 2022 Completion of College Preparation Graduates: Hispanic ELA Rate',
#  'District 2022 Completion of College Preparation Graduates: Hispanic Math Rate',
#  'District 2022 Completion of College Preparation Graduates: Hispanic ELA & Math Rate',
#  'District 2022 Completion of College Preparation Graduates: White ELA Rate',
#  'District 2022 Completion of College Preparation Graduates: White Math Rate',
#  'District 2022 Completion of College Preparation Graduates: White ELA & Math Rate',
#  'District 2022 Completion of College Preparation Graduates: Male ELA Rate',
#  'District 2022 Completion of College Preparation Graduates: Male Math Rate',
#  'District 2022 Completion of College Preparation Graduates: Male ELA & Math Rate',
#  'District 2022 Completion of College Preparation Graduates: Female ELA Rate',
#  'District 2022 Completion of College Preparation Graduates: Female Math Rate',
#  'District 2022 Completion of College Preparation Graduates: Female ELA & Math Rate',
#  'District 2022 Completion of College Preparation Graduates: Econ Disadv ELA Rate',
#  'District 2022 Completion of College Preparation Graduates: Econ Disadv Math Rate',
#  'District 2022 Completion of College Preparation Graduates: Econ Disadv ELA & Math Rate',
#  'District 2022 Completion of College Preparation Graduates: Special Ed ELA Rate',
#  'District 2022 Completion of College Preparation Graduates: Special Ed Math Rate',
#  'District 2022 Completion of College Preparation Graduates: Special Ed ELA & Math Rate',
#  'District 2022 Completion of College Preparation Graduates: At Risk ELA Rate',
#  'District 2022 Completion of College Preparation Graduates: At Risk Math Rate',
#  'District 2022 Completion of College Preparation Graduates: At Risk ELA & Math Rate',
#  'District 2021 Completion of College Preparation Graduates: All Students ELA Rate',
#  'District 2021 Completion of College Preparation Graduates: All Students Math Rate',
#  'District 2021 Completion of College Preparation Graduates: All Students ELA & Math Rate',
#  'District 2021 Completion of College Preparation Graduates: Hispanic ELA Rate',
#  'District 2021 Completion of College Preparation Graduates: Hispanic Math Rate',
#  'District 2021 Completion of College Preparation Graduates: Hispanic ELA & Math Rate',
#  'District 2021 Completion of College Preparation Graduates: White ELA Rate',
#  'District 2021 Completion of College Preparation Graduates: White Math Rate',
#  'District 2021 Completion of College Preparation Graduates: White ELA & Math Rate',
#  'District 2021 Completion of College Preparation Graduates: Male ELA Rate',
#  'District 2021 Completion of College Preparation Graduates: Male Math Rate',
#  'District 2021 Completion of College Preparation Graduates: Male ELA & Math Rate',
#  'District 2021 Completion of College Preparation Graduates: Female ELA Rate',
#  'District 2021 Completion of College Preparation Graduates: Female Math Rate',
#  'District 2021 Completion of College Preparation Graduates: Female ELA & Math Rate',
#  'District 2021 Completion of College Preparation Graduates: Econ Disadv ELA Rate',
#  'District 2021 Completion of College Preparation Graduates: Econ Disadv Math Rate',
#  'District 2021 Completion of College Preparation Graduates: Econ Disadv ELA & Math Rate',
#  'District 2021 Completion of College Preparation Graduates: Special Ed ELA Rate',
#  'District 2021 Completion of College Preparation Graduates: Special Ed Math Rate',
#  'District 2021 Completion of College Preparation Graduates: Special Ed ELA & Math Rate',
#  'District 2021 Completion of College Preparation Graduates: At Risk ELA Rate',
#  'District 2021 Completion of College Preparation Graduates: At Risk Math Rate',
#  'District 2021 Completion of College Preparation Graduates: At Risk ELA & Math Rate',
#  'COUNTY',
#  'REGION',
#  'DISTRICT',
#  'DISTNAME',
#  'CNTYNAME',
#  'DFLCHART',
#  'DFLALTED',
#  'ASVAB_STATUS']
